# %% [markdown]
# <a href="https://colab.research.google.com/github/Ohgangrae/ai/blob/main/%EC%95%88%EB%A9%B4%EC%9D%B8%EC%8B%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Client ID	: MwmzjwwFi_Gwi3LbOJOv
# Client Secret : Z9h5dAtPmC



import os         # 운영체제 접근
import sys        # 시스템 접근
import requests   # 웹 접근

client_id = "MwmzjwwFi_Gwi3LbOJOv"
client_secret = "Z9h5dAtPmC"

url = "https://openapi.naver.com/v1/vision/face"    #얼굴감지
# url = "https://openapi.naver.com/v1/vision/celebrity" # 유명인 얼굴인식


files = {'image': open('1.jpg', 'rb')} # 사진 파일이름

headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
response = requests.post(url,  files=files, headers=headers)

rescode = response.status_code
if(rescode==200):
    print (response.text)
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":252,"height":310},"faceCount":1},"faces":[{"roi":{"x":61,"y":117,"width":129,"height":129},"landmark":{"leftEye":{"x":88,"y":148},"rightEye":{"x":150,"y":149},"nose":{"x":120,"y":187},"leftMouth":{"x":98,"y":218},"rightMouth":{"x":149,"y":217}},"gender":{"value":"male","confidence":0.999999},"age":{"value":"30~34","confidence":1.0},"emotion":{"value":"neutral","confidence":0.999904},"pose":{"value":"frontal_face","confidence":0.999776}}]}

# %%
import json

parsed = json.loads(response.text)

type(parsed)
# Out:
# dict

# %%
print(parsed)
# Out:
# {'info': {'size': {'width': 327, 'height': 154}, 'faceCount': 8}, 'faces': [{'roi': {'x': 140, 'y': 43, 'width': 19, 'height': 19}, 'landmark': None, 'gender': {'value': 'female', 'confidence': 0.998054}, 'age': {'value': '53~57', 'confidence': 0.286441}, 'emotion': {'value': 'neutral', 'confidence': 0.465206}, 'pose': {'value': 'part_face', 'confidence': 0.667298}}, {'roi': {'x': 242, 'y': 12, 'width': 25, 'height': 25}, 'landmark': {'leftEye': {'x': 247, 'y': 20}, 'rightEye': {'x': 258, 'y': 17}, 'nose': {'x': 254, 'y': 25}, 'leftMouth': {'x': 252, 'y': 31}, 'rightMouth': {'x': 263, 'y': 28}}, 'gender': {'value': 'female', 'confidence': 0.998079}, 'age': {'value': '22~26', 'confidence': 0.776388}, 'emotion': {'value': 'smile', 'confidence': 0.915947}, 'pose': {'value': 'frontal_face', 'confidence': 0.538647}}, {'roi': {'x': 217, 'y': 37, 'width': 25, 'height': 25}, 'landmark': {'leftEye': {'x': 222, 'y': 42}, 'rightEye': {'x': 234, 'y': 41}, 'nose': {'x': 228, 'y': 46}, 'leftMouth': {'x': 223, 'y': 52}, 'rightMouth': {'x': 233, 'y': 51}}, 'gender': {'value': 'female', 'confidence': 0.949137}, 'age': {'value': '25~29', 'confidence': 0.476057}, 'emotion': {'value': 'smile', 'confidence': 0.987431}, 'pose': {'value': 'frontal_face', 'confidence': 0.600075}}, {'roi': {'x': 112, 'y': 29, 'width': 21, 'height': 21}, 'landmark': None, 'gender': {'value': 'male', 'confidence': 0.907911}, 'age': {'value': '38~42', 'confidence': 0.0456423}, 'emotion': {'value': 'neutral', 'confidence': 0.893957}, 'pose': {'value': 'right_face', 'confidence': 0.794487}}, {'roi': {'x': 111, 'y': 64, 'width': 20, 'height': 20}, 'landmark': None, 'gender': {'value': 'male', 'confidence': 0.977716}, 'age': {'value': '12~16', 'confidence': 0.0231555}, 'emotion': {'value': 'talking', 'confidence': 0.649451}, 'pose': {'value': 'right_face', 'confidence': 0.568212}}, {'roi': {'x': 183, 'y': 25, 'width': 19, 'height': 19}, 'landmark': {'leftEye': {'x': 187, 'y': 29}, 'rightEye': {'x': 196, 'y': 29}, 'nose': {'x': 191, 'y': 35}, 'leftMouth': {'x': 188, 'y': 41}, 'rightMouth': {'x': 195, 'y': 40}}, 'gender': {'value': 'male', 'confidence': 0.950627}, 'age': {'value': '15~19', 'confidence': 0.293707}, 'emotion': {'value': 'neutral', 'confidence': 0.989864}, 'pose': {'value': 'frontal_face', 'confidence': 0.875897}}, {'roi': {'x': 179, 'y': 55, 'width': 28, 'height': 28}, 'landmark': None, 'gender': {'value': 'female', 'confidence': 0.660266}, 'age': {'value': '61~65', 'confidence': 0.10882}, 'emotion': {'value': 'smile', 'confidence': 0.487142}, 'pose': {'value': 'false_face', 'confidence': 0.944538}}, {'roi': {'x': 74, 'y': 59, 'width': 25, 'height': 25}, 'landmark': None, 'gender': {'value': 'female', 'confidence': 0.997698}, 'age': {'value': '53~57', 'confidence': 0.0212053}, 'emotion': {'value': 'smile', 'confidence': 0.625517}, 'pose': {'value': 'false_face', 'confidence': 0.692902}}]}

# %%
print(json.dumps(parsed,indent=4))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 327,
#             "height": 154
#         },
#         "faceCount": 8
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 140,
#                 "y": 43,
#                 "width": 19,
#                 "height": 19
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.998054
#             },
#             "age": {
#                 "value": "53~57",
#                 "confidence": 0.286441
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.465206
#             },
#             "pose": {
#                 "value": "part_face",
#                 "confidence": 0.667298
#             }
#         },
#         {
#             "roi": {
#                 "x": 242,
#                 "y": 12,
#                 "width": 25,
#                 "height": 25
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 247,
#                     "y": 20
#                 },
#                 "rightEye": {
#                     "x": 258,
#                     "y": 17
#                 },
#                 "nose": {
#                     "x": 254,
#                     "y": 25
#                 },
#                 "leftMouth": {
#                     "x": 252,
#                     "y": 31
#                 },
#                 "rightMouth": {
#                     "x": 263,
#                     "y": 28
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.998079
#             },
#             "age": {
#                 "value": "22~26",
#                 "confidence": 0.776388
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.915947
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.538647
#             }
#         },
#         {
#             "roi": {
#                 "x": 217,
#                 "y": 37,
#                 "width": 25,
#                 "height": 25
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 222,
#                     "y": 42
#                 },
#                 "rightEye": {
#                     "x": 234,
#                     "y": 41
#                 },
#                 "nose": {
#                     "x": 228,
#                     "y": 46
#                 },
#                 "leftMouth": {
#                     "x": 223,
#                     "y": 52
#                 },
#                 "rightMouth": {
#                     "x": 233,
#                     "y": 51
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.949137
#             },
#             "age": {
#                 "value": "25~29",
#                 "confidence": 0.476057
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.987431
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.600075
#             }
#         },
#         {
#             "roi": {
#                 "x": 112,
#                 "y": 29,
#                 "width": 21,
#                 "height": 21
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.907911
#             },
#             "age": {
#                 "value": "38~42",
#                 "confidence": 0.0456423
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.893957
#             },
#             "pose": {
#                 "value": "right_face",
#                 "confidence": 0.794487
#             }
#         },
#         {
#             "roi": {
#                 "x": 111,
#                 "y": 64,
#                 "width": 20,
#                 "height": 20
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.977716
#             },
#             "age": {
#                 "value": "12~16",
#                 "confidence": 0.0231555
#             },
#             "emotion": {
#                 "value": "talking",
#                 "confidence": 0.649451
#             },
#             "pose": {
#                 "value": "right_face",
#                 "confidence": 0.568212
#             }
#         },
#         {
#             "roi": {
#                 "x": 183,
#                 "y": 25,
#                 "width": 19,
#                 "height": 19
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 187,
#                     "y": 29
#                 },
#                 "rightEye": {
#                     "x": 196,
#                     "y": 29
#                 },
#                 "nose": {
#                     "x": 191,
#                     "y": 35
#                 },
#                 "leftMouth": {
#                     "x": 188,
#                     "y": 41
#                 },
#                 "rightMouth": {
#                     "x": 195,
#                     "y": 40
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.950627
#             },
#             "age": {
#                 "value": "15~19",
#                 "confidence": 0.293707
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.989864
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.875897
#             }
#         },
#         {
#             "roi": {
#                 "x": 179,
#                 "y": 55,
#                 "width": 28,
#                 "height": 28
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.660266
#             },
#             "age": {
#                 "value": "61~65",
#                 "confidence": 0.10882
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.487142
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.944538
#             }
#         },
#         {
#             "roi": {
#                 "x": 74,
#                 "y": 59,
#                 "width": 25,
#                 "height": 25
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.997698
#             },
#             "age": {
#                 "value": "53~57",
#                 "confidence": 0.0212053
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.625517
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.692902
#             }
#         }
#     ]
# }

# %%
parsed.keys()
# Out:
# dict_keys(['info', 'faces'])

# %%
print(parsed['info'])
# Out:
# {'size': {'width': 327, 'height': 154}, 'faceCount': 8}

# %%
print(parsed['faces'])
# Out:
# [{'roi': {'x': 140, 'y': 43, 'width': 19, 'height': 19}, 'landmark': None, 'gender': {'value': 'female', 'confidence': 0.998054}, 'age': {'value': '53~57', 'confidence': 0.286441}, 'emotion': {'value': 'neutral', 'confidence': 0.465206}, 'pose': {'value': 'part_face', 'confidence': 0.667298}}, {'roi': {'x': 242, 'y': 12, 'width': 25, 'height': 25}, 'landmark': {'leftEye': {'x': 247, 'y': 20}, 'rightEye': {'x': 258, 'y': 17}, 'nose': {'x': 254, 'y': 25}, 'leftMouth': {'x': 252, 'y': 31}, 'rightMouth': {'x': 263, 'y': 28}}, 'gender': {'value': 'female', 'confidence': 0.998079}, 'age': {'value': '22~26', 'confidence': 0.776388}, 'emotion': {'value': 'smile', 'confidence': 0.915947}, 'pose': {'value': 'frontal_face', 'confidence': 0.538647}}, {'roi': {'x': 217, 'y': 37, 'width': 25, 'height': 25}, 'landmark': {'leftEye': {'x': 222, 'y': 42}, 'rightEye': {'x': 234, 'y': 41}, 'nose': {'x': 228, 'y': 46}, 'leftMouth': {'x': 223, 'y': 52}, 'rightMouth': {'x': 233, 'y': 51}}, 'gender': {'value': 'female', 'confidence': 0.949137}, 'age': {'value': '25~29', 'confidence': 0.476057}, 'emotion': {'value': 'smile', 'confidence': 0.987431}, 'pose': {'value': 'frontal_face', 'confidence': 0.600075}}, {'roi': {'x': 112, 'y': 29, 'width': 21, 'height': 21}, 'landmark': None, 'gender': {'value': 'male', 'confidence': 0.907911}, 'age': {'value': '38~42', 'confidence': 0.0456423}, 'emotion': {'value': 'neutral', 'confidence': 0.893957}, 'pose': {'value': 'right_face', 'confidence': 0.794487}}, {'roi': {'x': 111, 'y': 64, 'width': 20, 'height': 20}, 'landmark': None, 'gender': {'value': 'male', 'confidence': 0.977716}, 'age': {'value': '12~16', 'confidence': 0.0231555}, 'emotion': {'value': 'talking', 'confidence': 0.649451}, 'pose': {'value': 'right_face', 'confidence': 0.568212}}, {'roi': {'x': 183, 'y': 25, 'width': 19, 'height': 19}, 'landmark': {'leftEye': {'x': 187, 'y': 29}, 'rightEye': {'x': 196, 'y': 29}, 'nose': {'x': 191, 'y': 35}, 'leftMouth': {'x': 188, 'y': 41}, 'rightMouth': {'x': 195, 'y': 40}}, 'gender': {'value': 'male', 'confidence': 0.950627}, 'age': {'value': '15~19', 'confidence': 0.293707}, 'emotion': {'value': 'neutral', 'confidence': 0.989864}, 'pose': {'value': 'frontal_face', 'confidence': 0.875897}}, {'roi': {'x': 179, 'y': 55, 'width': 28, 'height': 28}, 'landmark': None, 'gender': {'value': 'female', 'confidence': 0.660266}, 'age': {'value': '61~65', 'confidence': 0.10882}, 'emotion': {'value': 'smile', 'confidence': 0.487142}, 'pose': {'value': 'false_face', 'confidence': 0.944538}}, {'roi': {'x': 74, 'y': 59, 'width': 25, 'height': 25}, 'landmark': None, 'gender': {'value': 'female', 'confidence': 0.997698}, 'age': {'value': '53~57', 'confidence': 0.0212053}, 'emotion': {'value': 'smile', 'confidence': 0.625517}, 'pose': {'value': 'false_face', 'confidence': 0.692902}}]

# %%
parsed['faces'][4]
# Out:
# {'age': {'confidence': 0.0231555, 'value': '12~16'},
#  'emotion': {'confidence': 0.649451, 'value': 'talking'},
#  'gender': {'confidence': 0.977716, 'value': 'male'},
#  'landmark': None,
#  'pose': {'confidence': 0.568212, 'value': 'right_face'},
#  'roi': {'height': 20, 'width': 20, 'x': 111, 'y': 64}}

# %%
import matplotlib.patches as patches  # 사진 수정 관련 모듈
import matplotlib.image as mpimg     # 사진 읽어오는 모듈
import matplotlib.pyplot as plt           # 사진 관련 기본 모듈

img = mpimg.imread('2.jpg')     # 사진 읽어오기
fig, ax = plt.subplots()                      # 사진을 표시할 액자틀과 사진틀 설정
ax.imshow(img)                               # 사진틀에 사진 삽입 

print(parsed['faces'][0]['roi'])
x,y,w,h = parsed['faces'][0]['roi'].values() # 인식한 얼굴의 roi 위치정보를 변수로 할당

re_face = patches.Rectangle((x,y),w,h, facecolor='none', edgecolor='r')  # 그 위치에 사각형을 표시 정보

ax.add_patch(re_face)                         # 기본 사진에 사각형 사진 수정
# Out:
# {'x': 140, 'y': 43, 'width': 19, 'height': 19}

# %%
import matplotlib.pyplot as plt          # 사진(그림) 관련 기본 모듈
import matplotlib.image as mpimg     # 사진 읽어오는 모듈
import matplotlib.patches as patches  # 사진 수정 관련 모듈

img = mpimg.imread('2.jpg')     # 사진 읽어오기
fig, ax = plt.subplots(figsize=(10,10))                      # 사진을 표시할 액자틀과 사진틀 설정
ax.imshow(img)                               # 사진틀에 사진 삽입 

for each in parsed['faces']:
  x,y,w,h = each['roi'].values() # 인식한 얼굴의 roi 위치정보를 변수로 할당
  re_face = patches.Rectangle((x,y),w,h, facecolor='none', edgecolor='r')  # 그 위치에 사각형을 표시 정보
  ax.add_patch(re_face)

# %%
parsed['faces'][0]

# 각각의 얼굴 옆에
# Out:
# {'age': {'confidence': 0.286441, 'value': '53~57'},
#  'emotion': {'confidence': 0.465206, 'value': 'neutral'},
#  'gender': {'confidence': 0.998054, 'value': 'female'},
#  'landmark': None,
#  'pose': {'confidence': 0.667298, 'value': 'part_face'},
#  'roi': {'height': 19, 'width': 19, 'x': 140, 'y': 43}}
